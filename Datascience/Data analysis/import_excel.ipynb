# %%
import pandas as pd

# %%
path= r"Data Analysis/Sample_Data.xlsx"

# %%
pd.read_excel(path) #It will read the sheet 1 of the file

# %%
pd.read_excel(path,sheet_name='Sheet_2')

# %% [markdown]
# That's it. Other parameters are similar/same as that of csv

# %% [markdown]
# # Reading txt files

# %% [markdown]
# its the same as of tsv. We just have to pass separator whatever separator is used in the txt file.

# %%
path='sample.txt'
pd.read_csv(path,sep='\t') #sep can be ' ', ':' , ';'
