# %% [markdown]
# <h1> Data Analysis Process</h1>
# <h3> 1. Data gathering</h3>
# <h3> 2. Data Accessing</h3>
# <h3> 3. Data cleaning</h3>
# <h3> 4. EDA</h3>

# %% [markdown]
# <h2>How do we do analysis? </h2>
# Asking questions -> Data wrangling -> EDA -> Drawing Conclusions -> Communicating Results

# %% [markdown]
# <h2> 1. Data Gathering </h2>

# %% [markdown]
# <h3> Data gathering can be done from: </h3>
# <h4> 1. csv files</h4>
# <h4> 2. API</h4>
# <h4> 3. Web scraping</h4>
# <h4> 4. Data bases</h4>

# %% [markdown]
# <h2>2. Accessing Data </h2>
# <h4>1. Finding the number of rows/columns(shape)</h4>
# <h4> 2. Data types of various columns (info()) </h4>
# <h4> 3. Checking for missing values (info())</h4>
#
# <h4> 4. Check for duplicate data (is_unique)</h4>
#
# <h4> 5. Memory occupied by the dataset (info)</h4>
#
# <h4> 6. High level mathematical overview of the data (describe)</h4>

# %% [markdown]
# <p><h2>3. Cleaning Data</h2>
# <h4>1. Missing Data (eg. Mean)</h4>
# <h4>2. Remove duplicate data (drop_duplicates)</h4>
# <h4>3. Incorrect data type(astype)</h4></p>

# %% [markdown]
# <h2>4. Exploratory Data Analysis ( EDA)</h2>
# <h4>a. Exploring Data  </h4>
# <h5>          -Finding Correlation and Covariance</h5>
# <h5>          -Doing univariate and multivariate analysis</h5>
# <h5>          -Plotting graphs(Data visualization)</h5>
# <h4>b.Augmenting Data</h4>
# <h5> - Removing outliers</h5>
# <h5> - Merging Dataframes</h5>
# <h5> - Adding new Column</h5>
# <h4>c. Drawing Conclusions</h4>
# <h5> - Machine Learning</h5>
# <h5> - Inferential Statistics</h5>
# <h5> - Descriptive Statistics</h5>

# %% [markdown]
# <h2>5. Communicating Results/ Data Storytelling</h2>
# <h4>a. Reports</h4>
# <h4>b. PPTs/Slide decks</h4>
# <h4>c. Blog Post</h4>
# <h4>d. In person</h4>
